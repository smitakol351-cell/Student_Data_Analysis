# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_csv('C:/Users/User/OneDrive/Desktop/CEDMAP/Data Analysis/Data/raw.csv')
# Out:
#       gender race_ethnicity parental_level_of_education         lunch  \
# 0     female        group B           bachelor's degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 997   female        group C                 high school  free/reduced
# 998   female        group D                some college      standard
# 999   female        group D                some college  free/reduced
# 1000  female        group D                some college  free/reduced
# 1001  female        group D                some college  free/reduced
#
#      test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
df=pd.read_csv('C:/Users/User/OneDrive/Desktop/CEDMAP/Data Analysis/Data/raw.csv')
df
# Out:
#       gender race_ethnicity parental_level_of_education         lunch  \
# 0     female        group B           bachelor's degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 997   female        group C                 high school  free/reduced
# 998   female        group D                some college      standard
# 999   female        group D                some college  free/reduced
# 1000  female        group D                some college  free/reduced
# 1001  female        group D                some college  free/reduced
#
#      test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
df=pd.read_csv('C:/Users/User/OneDrive/Desktop/CEDMAP/Data Analysis/Data/raw.csv')
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %%
df.iloc[:10]
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
df.loc[10:20]
# Out:
#     gender race_ethnicity parental_level_of_education         lunch  \
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# 13    male        group A                some college      standard
# 14  female        group A             master's degree      standard
# 15  female        group C            some high school      standard
# 16    male        group C                 high school      standard
# 17  female        group B            some high school  free/reduced
# 18    male        group C             master's degree  free/reduced
# 19  female        group C          associate's degree  free/reduced
# 20    male        group D                 high school      standard
#
#    test_preparation_course  math_score  reading_score  writing_score
# 10                    none          58             54             52
# ...

# %%
df.describe(include='all')
# Out:
#         gender race_ethnicity parental_level_of_education     lunch  \
# count     1002           1002                        1002      1002
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       520            319                         228       645
# mean       NaN            NaN                         NaN       NaN
# std        NaN            NaN                         NaN       NaN
# min        NaN            NaN                         NaN       NaN
# 25%        NaN            NaN                         NaN       NaN
# 50%        NaN            NaN                         NaN       NaN
# 75%        NaN            NaN                         NaN       NaN
# max        NaN            NaN                         NaN       NaN
#
#        test_preparation_course   math_score  reading_score  writing_score
# count                     1002  1002.000000    1002.000000    1002.000000
# ...

# %%
df.isna()
# Out:
#       gender  race_ethnicity  parental_level_of_education  lunch  \
# 0      False           False                        False  False
# 1      False           False                        False  False
# 2      False           False                        False  False
# 3      False           False                        False  False
# 4      False           False                        False  False
# ...      ...             ...                          ...    ...
# 997    False           False                        False  False
# 998    False           False                        False  False
# 999    False           False                        False  False
# 1000   False           False                        False  False
# 1001   False           False                        False  False
#
#       test_preparation_course  math_score  reading_score  writing_score
# 0                       False       False          False          False
# ...

# %%
df.isna().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %%
df.shape
# Out:
# (1002, 8)

# %%
df["Average_Score"]=df["math_score"]+df["reading_score"]+df["writing_score"]/3
df
# Out:
#       gender race_ethnicity parental_level_of_education         lunch  \
# 0     female        group B           bachelor's degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 997   female        group C                 high school  free/reduced
# 998   female        group D                some college      standard
# 999   female        group D                some college  free/reduced
# 1000  female        group D                some college  free/reduced
# 1001  female        group D                some college  free/reduced
#
#      test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
import matplotlib.pyplot as plt
plt.hist([df["math_score"],df["reading_score"],df["writing_score"]],bins=15,edgecolor='black',alpha=0.7,histtype="barstacked",label=["Math", "Reading", "Writing"])
plt.title("All Scores (Math, Reading, Writing)", fontsize=14, fontweight="bold")

plt.xlabel("Scores", fontsize=12)
plt.show()

# %%
df.iloc[:10]
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
df["All_Score"]=df["math_score"]+df["reading_score"]+df["writing_score"]
df
# Out:
#       gender race_ethnicity parental_level_of_education         lunch  \
# 0     female        group B           bachelor's degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 997   female        group C                 high school  free/reduced
# 998   female        group D                some college      standard
# 999   female        group D                some college  free/reduced
# 1000  female        group D                some college  free/reduced
# 1001  female        group D                some college  free/reduced
#
#      test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
import seaborn as sns
plt.hist(df["All_Score"],bins=15,edgecolor='black',alpha=0.7)
plt.title("All Scores Combined", fontsize=14, fontweight="bold")
plt.xlabel("Scores", fontsize=12)
plt.grid()
plt.show()

# %%
plt.hist(df["reading_score"],bins=15,edgecolor='black',alpha=0.7)
plt.show()

# %%
sd=df.groupby("gender")['All_Score'].mean()
sd
# Out:
# gender
# female    208.863462
# male      197.512448
# Name: All_Score, dtype: float64

# %%
sns.barplot(sd,edgecolor='black',alpha=0.7,color='green')
plt.show()

# %%
df
# Out:
#       gender race_ethnicity parental_level_of_education         lunch  \
# 0     female        group B           bachelor's degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 997   female        group C                 high school  free/reduced
# 998   female        group D                some college      standard
# 999   female        group D                some college  free/reduced
# 1000  female        group D                some college  free/reduced
# 1001  female        group D                some college  free/reduced
#
#      test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
def  file_load(file_path):
    df=pd.read_csv(file_path)
    return df

# %%
df=file_load('C:/Users/User/OneDrive/Desktop/CEDMAP/Data Analysis/Data/raw.csv')
df
# Out:
#       gender race_ethnicity parental_level_of_education         lunch  \
# 0     female        group B           bachelor's degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 997   female        group C                 high school  free/reduced
# 998   female        group D                some college      standard
# 999   female        group D                some college  free/reduced
# 1000  female        group D                some college  free/reduced
# 1001  female        group D                some college  free/reduced
#
#      test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
import streamlit as st
st.set_page_config(
    page_title="Student Performance Analysis",
    page_icon="📊",
    layout="wide")
st.title("Student Performance Analysis")
st.write("This application analyzes student performance data.")
# Out:
# 2025-09-13 12:48:44.570 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-13 12:48:44.570 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-13 12:48:45.650
# ...
#   command:
#
#     streamlit run C:\Users\User\AppData\Roaming\Python\Python310\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-09-13 12:48:45.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-13 12:48:45.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-13 12:48:45.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
